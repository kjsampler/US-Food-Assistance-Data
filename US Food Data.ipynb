# %% [markdown]
# The purpose of this notebook will be to intake the data, clean, and start making explorations. If a question is decided on, the cleaning can be tailored to the needs of the project.

# %% [markdown]
# Week 6/14 - 6/20 To-Do:
# * figure out FY spreadsheets
# * create individual dataframes
# * consider merging similar dataframes together
# * identify and extract null values
# * start visualizations

# %%
import pandas as pd

# %% [markdown]
# data:
#
#     est13_16us
#
#         est13us
#         est14us
#         est15us
#         est16us
#     SNAP_FY2010_FY2020
#         FY10
#         FY11
#         ...
#         FY20
#     WICAgencies2013ytd ... WICAgencies2016ytd
#         Average_Food_Cost_Per_Person
#         Children_Participating
#         Food_Costs
#         Infants_Fully_Breastfed
#         Infants_Fully_Formula-fed
#         Infants_Partially_Breastfed
#         Nut_Services_Admin_Costs
#         Postpartum_Women_Participating
#         Pregnant_Women_Participating
#         Rebates_Received
#         Total_Breastfeeding_Women
#         Total_Infants
#         Total_Number_of_Participants
#         Total_Women
#         Women_Fully_Breastfeeding
#         Women_Partially_Breastfeeding
#     SNAP_history_1969_2019

# %% [markdown]
# Now that I have a schema, time to start exploring this data
# * Check out WIC categories (breadth of info)
# * Columns of SNAP history (and null values)
# * open at least one of each and see what it's about!

# %% [markdown]
# # Investigate est13_16us folder

# %%
est13_df = pd.read_csv('Food Assistance Data/data/est13_16us/est13us.csv')

# %%
est13_df.head()
# Out:
#   Geographic Information   Unnamed: 1     Unnamed: 2  \
# 0        State FIPS Code  Postal Code           Name
# 1                     00           US  United States
# 2                     01           AL        Alabama
# 3                     02           AK         Alaska
# 4                     04           AZ        Arizona
#
#                      All Ages          Unnamed: 4          Unnamed: 5  \
# 0  Poverty Estimate, All Ages  90% CI Lower Bound  90% CI Upper Bound
# 1                    48810868            48554692            49067044
# 2                      889091              873141              905041
# 3                       72643               69056               76230
# 4                     1206948             1184107             1229789
#
#                   Unnamed: 6          Unnamed: 7          Unnamed: 8  \
# 0  Poverty Percent, All Ages  90% CI Lower Bound  90% CI Upper Bound
# 1                       15.8                15.7                15.9
# ...

# %%
est13_df.columns
#if i use the est13_16us folder I will have to convert the first row to be the column names
# Out:
# Index(['Geographic Information', 'Unnamed: 1', 'Unnamed: 2', 'All Ages',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Age 0-17', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Age 5-17 in Families', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Median Household Income',
#        'Unnamed: 22', 'Unnamed: 23', 'Age 0-4', 'Unnamed: 25', 'Unnamed: 26',
#        'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29'],
#       dtype='object')

# %%
est14_df = pd.read_csv('Food Assistance Data/data/est13_16us/est14us.csv')
est14_df.head()
# Out:
#   Geographic Information   Unnamed: 1     Unnamed: 2  \
# 0        State FIPS Code  Postal Code           Name
# 1                     00           US  United States
# 2                     01           AL        Alabama
# 3                     02           AK         Alaska
# 4                     04           AZ        Arizona
#
#                      All Ages          Unnamed: 4          Unnamed: 5  \
# 0  Poverty Estimate, All Ages  90% CI Lower Bound  90% CI Upper Bound
# 1                    48208387            47966830            48449944
# 2                      905682              888317              923047
# 3                       81622               77611               85633
# 4                     1195889             1175667             1216111
#
#                   Unnamed: 6          Unnamed: 7          Unnamed: 8  \
# 0  Poverty Percent, All Ages  90% CI Lower Bound  90% CI Upper Bound
# 1                       15.5                15.4                15.6
# ...

# %%
len(est14_df)
# Out:
# 53

# %%
est15_df = pd.read_csv('Food Assistance Data/data/est13_16us/est15us.csv')
est15_df.head()
# Out:
#   Geographic Information   Unnamed: 1     Unnamed: 2  \
# 0        State FIPS Code  Postal Code           Name
# 1                     00           US  United States
# 2                     01           AL        Alabama
# 3                     02           AK         Alaska
# 4                     04           AZ        Arizona
#
#                      All Ages          Unnamed: 4          Unnamed: 5  \
# 0  Poverty Estimate, All Ages  90% CI Lower Bound  90% CI Upper Bound
# 1                    46153077            45878016            46428138
# 2                      875853              859781              891925
# 3                       74941               71399               78483
# 4                     1159046             1136666             1181426
#
#                   Unnamed: 6          Unnamed: 7          Unnamed: 8  \
# 0  Poverty Percent, All Ages  90% CI Lower Bound  90% CI Upper Bound
# 1                       14.7                14.6                14.8
# ...

# %%
est16_df = pd.read_csv('Food Assistance Data/data/est13_16us/est16us.csv')
est16_df.head()
# Out:
#   Geographic Information   Unnamed: 1     Unnamed: 2  \
# 0        State FIPS Code  Postal Code           Name
# 1                     00           US  United States
# 2                     01           AL        Alabama
# 3                     02           AK         Alaska
# 4                     04           AZ        Arizona
#
#                      All Ages          Unnamed: 4          Unnamed: 5  \
# 0  Poverty Estimate, All Ages  90% CI Lower Bound  90% CI Upper Bound
# 1                    44268996            44022086            44515906
# 2                      814197              796927              831467
# 3                       71916               67813               76019
# 4                     1107153             1086482             1127824
#
#                   Unnamed: 6          Unnamed: 7          Unnamed: 8  \
# 0  Poverty Percent, All Ages  90% CI Lower Bound  90% CI Upper Bound
# 1                         14                13.9                14.1
# ...

# %% [markdown]
# At first blush these all seem to match. I'll have to do more research as to what this dataframe is actually telling me, and do some cleaning to make it usable.

# %% [markdown]
# # SNAP_FY2010_FY2020

# %%
FY10_df = pd.read_excel('Food Assistance Data/data/SNAP_FY2010_FY2020/FY10.xls')
FY10_df.head()
# Out:
#   National Data Bank Version 8.2 - Supplemental Nutrition Assistance Program  \
# 0  SNAP Monthly State Participation and Benefit S...
# 1                              Fiscal Year and Month
# 2                                                NaN
# 3                                                NaN
# 4                                        Connecticut
#
#                                    Unnamed: 1 Unnamed: 2  \
# 0                                         NaN        NaN
# 1                            Participation 1/        NaN
# 2                                   Household    Persons
# 3  ----------------- Number -----------------        NaN
# 4                                         NaN        NaN
#
#                                           Unnamed: 3  Unnamed: 4 01/15/2015
# 0                                                NaN         NaN        NaN
# 1                                            Benefit         NaN        NaN
# ...

# %% [markdown]
# This has the same issue- the columns are not named. Also it looks like there may be significantly more NaNs to deal with
# ... is this in long format instead of wide???
#
# Here's the deal- it's actually very beautifully formatted in Excel. If I decide to use this dataset, I'll have to decide if it is efficient to format it into a datframe though. Will include image of formatted data below

# %% [markdown]
# <img src = "Food Assistance Data/data/SNAP_FY2010_FY2020/FY format image.png">

# %% [markdown]
# It is my belief that the tabs at the bottom (NERO, MARO, SERO, etc) are different regions of the US. I'm not sure how those have been added into the dataframe.

# %% [markdown]
# It's going to be tedious but I think I should open all of the FY files and see if I can get any insight as to what this is supposed to look like.
#
# All files appear to match (on a surface level). Commenting out for cleanliness until cleaning steps are ascertained.

# %% [markdown]
# ## Subtask: Write steps for cleaning

# %% [markdown]
# The first step, I think, is to decide what I want this to look like in a df. Will research and include image below.
# Consider using pd.pivot_table()

# %% [markdown]
# With the ultimate goal of combining all data into one large dataframe, I think this would be the most efficient layout:

# %% [markdown]
# It appears pandas is only reading one sheet out of 8 in the file.
# And now I'm wondering if each year is going to be made of several regional dataframes.

# %%
xls_10 = pd.ExcelFile('Food Assistance Data/data/SNAP_FY2010_FY2020/FY10.xls')
nero_10 = pd.read_excel(xls_10, 'NERO')
maro_10 = pd.read_excel(xls_10, 'MARO')
sero_10 = pd.read_excel(xls_10, 'SERO')
mwro_10 = pd.read_excel(xls_10, 'MWRO')
swro_10 = pd.read_excel(xls_10, 'SWRO ')
mpro_10 = pd.read_excel(xls_10, 'MPRO')
wro_10 = pd.read_excel(xls_10, 'WRO')
summary_10 = pd.read_excel(xls_10, 'US Summary ')

# %%
xls_10.sheet_names
#'SWRO' and 'US Summary' have a space in the sheet name, so at first the code above errored
#I think in future year's data I will just generate the list of names to start
# Out:
# ['NERO', 'MARO', 'SERO', 'MWRO', 'SWRO ', 'MPRO', 'WRO', 'US Summary ']

# %%
nero_10.head()
# Out:
#   National Data Bank Version 8.2 - Supplemental Nutrition Assistance Program  \
# 0  SNAP Monthly State Participation and Benefit S...
# 1                              Fiscal Year and Month
# 2                                                NaN
# 3                                                NaN
# 4                                        Connecticut
#
#                                    Unnamed: 1 Unnamed: 2  \
# 0                                         NaN        NaN
# 1                            Participation 1/        NaN
# 2                                   Household    Persons
# 3  ----------------- Number -----------------        NaN
# 4                                         NaN        NaN
#
#                                           Unnamed: 3  Unnamed: 4 01/15/2015
# 0                                                NaN         NaN        NaN
# 1                                            Benefit         NaN        NaN
# ...

# %%
maro_10.head()
# Out:
#   National Data Bank Version 8.2 - Supplemental Nutrition Assistance Program  \
# 0  SNAP Monthly State Participation and Benefit S...
# 1                              Fiscal Year and Month
# 2                                                NaN
# 3                                                NaN
# 4                                           Delaware
#
#                                    Unnamed: 1 Unnamed: 2  \
# 0                                         NaN        NaN
# 1                            Participation 1/        NaN
# 2                                   Household    Persons
# 3  ----------------- Number -----------------        NaN
# 4                                         NaN        NaN
#
#                                           Unnamed: 3  Unnamed: 4 01/15/2015
# 0                                                NaN         NaN        NaN
# 1                                            Benefit         NaN        NaN
# ...

# %% [markdown]
# That seems to be exactly what's happening here. So for each FY, there will be 8 dataframes for each region.
# Of course, the ultimate goal will be to combine all years/regions into one large dataframe to see changes over time.

# %%
xls_11 = pd.ExcelFile('Food Assistance Data/data/SNAP_FY2010_FY2020/FY11.xls')
xls_11.sheet_names
# Out:
# ['NERO', 'MARO', 'SERO', 'MWRO', 'SWRO ', 'MPRO', 'WRO', 'US Summary ']

# %%
nero_11 = pd.read_excel(xls_11, 'NERO')
maro_11 = pd.read_excel(xls_11, 'MARO')
sero_10 = pd.read_excel(xls_10, 'SERO')
mwro_10 = pd.read_excel(xls_10, 'MWRO')
swro_10 = pd.read_excel(xls_10, 'SWRO ')
mpro_10 = pd.read_excel(xls_10, 'MPRO')
wro_10 = pd.read_excel(xls_10, 'WRO')
summary_10 = pd.read_excel(xls_10, 'US Summary ')

# %%
# FY12_df = pd.read_excel('Food Assistance Data/data/SNAP_FY2010_FY2020/FY12.xls')
# FY12_df.head()

# %%
# FY13_df = pd.read_excel('Food Assistance Data/data/SNAP_FY2010_FY2020/FY13.xls')
# FY13_df.head()

# %%
# FY14_df = pd.read_excel('Food Assistance Data/data/SNAP_FY2010_FY2020/FY14.xls')
# FY14_df.head()

# %%
# FY15_df = pd.read_excel('Food Assistance Data/data/SNAP_FY2010_FY2020/FY15.xls')
# FY15_df.head()

# %%
# FY16_df = pd.read_excel('Food Assistance Data/data/SNAP_FY2010_FY2020/FY16.xls')
# FY16_df.head()

# %%
# FY17_df = pd.read_excel('Food Assistance Data/data/SNAP_FY2010_FY2020/FY17.xls')
# FY17_df.head()

# %%
# FY18_df = pd.read_excel('Food Assistance Data/data/SNAP_FY2010_FY2020/FY18.xls')
# FY18_df.head()

# %%
# FY19_df = pd.read_excel('Food Assistance Data/data/SNAP_FY2010_FY2020/FY19.xls')
# FY19_df.head()

# %%
# FY20_df = pd.read_excel('Food Assistance Data/data/SNAP_FY2010_FY2020/FY20.xls')
# FY20_df.head()

# %% [markdown]
# # SNAP_history_1969_2019

# %%
snap_df = pd.read_csv("Food Assistance Data/data/SNAP_history_1969_2019.csv")
snap_df.head()
# Out:
#   Fiscal Year Average Participation  Average Benefit Per Person  \
# 0        1969                 2,878                        6.63
# 1        1970                 4,340                       10.55
# 2        1971                 9,368                       13.55
# 3        1972                11,109                       13.48
# 4        1973                12,166                       14.60
#
#   Total Benefits(M) Other Costs Total Costs(M)
# 0            228.80       21.70         250.50
# 1            549.70       27.20         576.90
# 2          1,522.70       53.20       1,575.90
# 3          1,797.30       69.40       1,866.70
# 4          2,131.40       76.00       2,207.40

# %%
#okay... now THAT'S pretty
